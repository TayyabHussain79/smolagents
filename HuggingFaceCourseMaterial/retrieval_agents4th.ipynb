# %% [markdown]
# ## Let's install the dependencies and login to our HF account to access the Inference API
#
# If you haven't installed `smolagents` yet, you can do so by running the following command:the dependencies and login to our HF account to access the Inference API

# %%
# !pip install smolagents
# Out:
# Requirement already satisfied: smolagents in /usr/local/lib/python3.11/dist-packages (1.19.0)
# Requirement already satisfied: huggingface-hub>=0.31.2 in /usr/local/lib/python3.11/dist-packages (from smolagents) (0.33.0)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from smolagents) (2.32.3)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.11/dist-packages (from smolagents) (13.9.4)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in /usr/local/lib/python3.11/dist-packages (from smolagents) (11.2.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from smolagents) (1.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.31.2->smolagents) (1.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3.1.4->smolagents) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->smolagents) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->smolagents) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->smolagents) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->smolagents) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->smolagents) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.9.4->smolagents) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)

# %% [markdown]
# Let's also login to the Hugging Face Hub to have access to the Inference API.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Basic Retrieval with DuckDuckGo
#
# Let's build a simple agent that can search the web using DuckDuckGo. This agent will retrieve information and synthesize responses to answer queries. With Agentic RAG, Alfred's agent can:
#
# * Search for latest superhero party trends
# * Refine results to include luxury elements
# * Synthesize information into a complete plan
#
# Here's how Alfred's agent can achieve this:

# %%
# !pip install duckduckgo-search
# Out:
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.0.4-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from duckduckgo-search) (8.2.1)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-0.15.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from duckduckgo-search) (5.4.0)
# Downloading duckduckgo_search-8.0.4-py3-none-any.whl (18 kB)
# Downloading primp-0.15.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 31.6 MB/s eta 0:00:00
# Installing collected packages: primp, duckduckgo-search
# Successfully installed duckduckgo-search-8.0.4 primp-0.15.0

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

# Initialize the search tool
search_tool = DuckDuckGoSearchTool()

# Initialize the model
model = InferenceClientModel()

agent = CodeAgent(
    model = model,
    tools=[search_tool]
)

# Example usage
response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering.             │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   luxury_party_ideas = web_search("luxury superhero-themed party ideas decorations entertainment catering")
#   print(luxury_party_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [15 Ideas for Superhero-Themed Events -
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13479192/15-ideas-for-superheroth
# emed-events)
# Primary colors are a distinct part of any superhero's costume, and that visual inspired the monochromatic menu for
# Raw's industry party in Toronto. The architectural firm passed items such as Parisienne potatoes topped with
# blue-dyed whitefish mousse and blue sea salt, beef tartare with beet-dyed horseradish in heirloom tomatoes
# (pictured), and ...
#
# [130 Best SUPERHERO PARTY DECORATIONS ideas in 2025 -
# Pinterest](https://www.pinterest.com/balloonentertainmentdeltona/superhero-party-decorations/)
# Apr 26, 2025 - Balloon decorations and party ideas for any event or party. See more ideas about superhero party
# decorations, superhero party, superhero birthday.
#
# [How to Host a superhero Party? - Captain Fantastic US](https://cfparties.com/blog/how-to-host-superhero-party/)
# Learn to host a superhero party with themed decorations, costumes, and activities. How to Host a Superhero Party?
# Discover now!
#
# [Superhero Theme Party Ideas for Adults to Create an Unforgettable
# ...](https://partyideaszone.com/superhero-theme-party-ideas-for-adults/)
# Unleash your inner hero with our ultimate guide to hosting an unforgettable superhero-themed party for adults!
# Explore creative costume ideas, vibrant decorations, and mouthwatering themed snacks and drinks.
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# Superhero party ideas by an award winning professional party planner including ideas for invitations, party food &
# drinks, decorations, and party supplies
#
# [Superhero-Themed Party Ideas & Decorations |
# CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# Superhero-themed parties have become a beloved trend, offering an exciting way to celebrate special occasions. The
# thrill of donning capes and masks, the vibrant decorations, and the heroic atmosphere make these parties a hit
# among kids and adults alike. In this guide, we'll explore Marvel superhero party ideas, ensuring your celebration
# is as epic as the comics and movies themselves ...
#
# [Super Hero Party Supplies: Transform Your Party Space Into a Heroic
# ...](https://www.bulkpartysupplies.com/collections/super-hero-party-theme)
# Honor your super hero and transform your party space into a heroic wonderland! Our amazing super hero themed
# decorations and party accessories will help you create an unforgettable event. From masks and capes to banners and
# tableware, you'll find everything you need to make your special day heroic. Let your guests feel like super heroes
# as they celebrate the special occasion!
#
# [Best Superhero Party Theme Ideas - Captain
# Fantastic](https://captain-fantastic.co.uk/blog/best-superhero-party-theme-ideas/)
# Elevate your event with the Superhero Party Theme—unleash an unforgettable adventure of heroism and excitement.
#
# [56 Superhero party catering ideas -
# Pinterest](https://www.pinterest.com/alexmlopez/superhero-party-catering-ideas/)
# Nov 21, 2018 - Explore Alex Lopez Arguelles's board "Superhero party catering ideas" on Pinterest. See more ideas
# about superhero party, party, superhero birthday party.
#
# [The Best Superhero Party Ideas For An Epic Party](https://smartpartyplanning.com/superhero-party-ideas/)
# Win the status of supermom with these superhero party ideas. Includes ideas for decorations, food and party games
# that kids will love.
#
# Out: None
# [Step 1: Duration 3.66 seconds| Input tokens: 2,005 | Output tokens: 66]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Analyzing BizBash results
#   bizbash_results = web_search("Bizbash superhero-themed luxury party ideas decorations entertainment catering")
#   print("BizBash Results:", bizbash_results)
#
#   # Analyzing By a Pro results
#   byapro_results = web_search("By a Pro superhero-themed luxury party ideas decorations entertainment catering")
#   print("By a Pro Results:", byapro_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# BizBash Results: ## Search Results
#
# [15 Ideas for Superhero-Themed Events -
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13479192/15-ideas-for-superheroth
# emed-events)
# Primary colors are a distinct part of any superhero's costume, and that visual inspired the monochromatic menu for
# Raw's industry party in Toronto. The architectural firm passed items such as Parisienne potatoes topped with
# blue-dyed whitefish mousse and blue sea salt, beef tartare with beet-dyed horseradish in heirloom tomatoes
# (pictured), and ...
#
# [15 Ideas for Superhero-Themed Events | BizBash in 2025 | Superhero
# ...](https://www.pinterest.com/pin/15-ideas-for-superherothemed-events--415175659421472578/)
# PWE ensured from the entrance to exit the venue was covered in superhero details. From a Batmobile at the entrance
# to each guest getting their own superhero or villain wristband throughout the night, from specialty cocktails
# labeled appropriately for the event, to comic book decorated tabletops, this event was one to remember.
#
# [How to Host a superhero Party? - Captain Fantastic US](https://cfparties.com/blog/how-to-host-superhero-party/)
# Learn to host a superhero party with themed decorations, costumes, and activities. How to Host a Superhero Party?
# Discover now!
#
# [10 Creative Ideas to Make Your Corporate Events More
# Engaging](https://www.gigwise.com/creative-ideas-to-make-your-corporate-events-more-engaging/)
# Here are 10 fresh ideas designed to transform your corporate events from monotonous meetings into experiences
# people actually look forward to! 1. Interactive Icebreakers and Networking Games
#
# [Super Hero Theme -
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13360306/super-hero-theme)
# At a premiere party for Amazon's series The Tick, held in New York in August 2017, custom props and decor
# incorporated superhero and comic-book nuances in a playful way.
#
# [Superhero theme |
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13357156/superhero-theme)
# 16 Design and Catering Ideas to Inspire Your Summer Olympics-Themed Events From edible tennis balls to branded
# rock-climbing walls, these concepts are ideal for gatherings tied to the upcoming Olympic Games in Paris.
#
# [THEME DECOR IDEAS |
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13358439/theme-decor-ideas)
# Primary colors are a distinct part of any superhero's costume, and that visual inspired the monochromatic menu for
# Raw's industry party in Toronto. The architectural firm passed items such as Parisienne potatoes topped with
# blue-dyed whitefish mousse and blue sea salt, beef tartare with beet-dyed horseradish in heirloom tomatoes
# (pictured), and ...
#
# [13 Corporate Holiday Party Ideas Inspired by 'Succession' |
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/22923039/13-corporate-holiday-par
# ty-ideas-inspired-by-succession)
# The family of Waystar RoyCo, the fictional global media and entertainment conglomerate based in New York City from
# the TV series Succession, aren't the most fun folks, but they do know how to throw an epic event. If you're
# planning a big bash for a corporation or looking for high-end, luxurious inspiration for a holiday party, keep
# reading for ideas that the Roy crew would approve of...
#
# [How to Start a Birthday Party Business: Themes, Planning &
# Marketing](https://www.bookeo.com/news/2025/06/start-birthday-party-business-themes-planning-marketing/)
# Start a birthday party business with ease, learn how to plan themes, market your services, manage events, and turn
# celebrations into steady income.
#
# [15 Ideas for Superhero-Themed Events | BizBash | Superhero theme
# ...](https://www.pinterest.com/pin/15-ideas-for-superherothemed-events--427842033366389846/)
# NACE or The National Association of Catering Executives hosts an amazing Tablescapes event every year and this
# year, they kindly asked me to be the judge! I loved seeing all of the amazing table settings that their members set
# to show off their Superhero's Theme.
# By a Pro Results: ## Search Results
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# Superhero party ideas by an award winning professional party planner including ideas for invitations, party food &
# drinks, decorations, and party supplies
#
# [15 Ideas for Superhero-Themed Events -
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13479192/15-ideas-for-superheroth
# emed-events)
# Given the popularity of other films and TV shows about comic book characters and people with superhuman powers,
# it's no surprise hosts have been incorporating superhero themes into their events. Here's a look at different ideas
# for adding cartoon-like visuals and references to caped crusaders at your next affair.
#
# [130 Best SUPERHERO PARTY DECORATIONS ideas in 2025 -
# Pinterest](https://www.pinterest.com/balloonentertainmentdeltona/superhero-party-decorations/)
# Apr 26, 2025 - Balloon decorations and party ideas for any event or party. See more ideas about superhero party
# decorations, superhero party, superhero birthday.
#
# [Superhero Theme Party Ideas for Adults to Create an Unforgettable
# ...](https://partyideaszone.com/superhero-theme-party-ideas-for-adults/)
# Unleash your inner hero with our ultimate guide to hosting an unforgettable superhero-themed party for adults!
# Explore creative costume ideas, vibrant decorations, and mouthwatering themed snacks and drinks.
#
# [How to Host a superhero Party? - Captain Fantastic US](https://cfparties.com/blog/how-to-host-superhero-party/)
# Design themed invitations that reflect the chosen superhero theme, incorporating iconic symbols and colors to
# excite your guests. When it comes to decorations, let your imagination soar! Transform the venue with
# superhero-themed decor, including banners, balloons, and centerpieces featuring your favorite characters.
#
# [Superhero-Themed Party Ideas & Decorations |
# CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# Marvel™ Superhero-Themed Party Ideas Superhero-themed parties have become a beloved trend, offering an exciting way
# to celebrate special occasions. The thrill of donning capes and masks, the vibrant decorations, and the heroic
# atmosphere make these parties a hit among kids and adults alike.
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# 24 incredible superhero party ideas that kids will love and make adults wish they were kids again. From decor
# ideas, party foods, and costume ideas to superhero-themed activities, we have all of your party needs covered.
#
# [Creative Event Themes: Superhero Party](https://nationaleventpros.com/creative-event-themes-superhero-party/)
# Then, ask guests to come up with superpowers for each other, recognizing the contributions of their team members to
# the greater good. Guests will go home filled up, and team morale will skyrocket. Everyone has a little superhero in
# their soul, after all. For even more great party theme ideas, check out our list of 100 Creative Event Themes.
#
# [Best Superhero Party Theme Ideas - Captain
# Fantastic](https://captain-fantastic.co.uk/blog/best-superhero-party-theme-ideas/)
# Elevate your event with the Superhero Party Theme—unleash an unforgettable adventure of heroism and excitement.
#
# [Planning a Superhero Themed Party: Ideas and
# Inspiration](https://partywhammy.com/planning-a-superhero-themed-party-ideas-and-inspiration/)
# Some of the key items you will need for a successful superhero event include: decorations (balloons, banners, signs
# etc.), costumes, props and snacks (or catering if hiring) as well as music equipment (PA systems, speaker stands
# etc.) if hosting in a larger venue.
#
# Out: None
# [Step 2: Duration 5.96 seconds| Input tokens: 4,950 | Output tokens: 207]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extract key points from BizBash
#   bizbash_url =
#   "https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13479192/15-ideas-for-superherothemed
#   -events"
#   bizbash_page_content = web_search(bizbash_url)
#   print("BizBash Page Content:", bizbash_page_content)
#
#   # Extract key points from By a Pro
#   byapro_url = "https://party-ideas-by-a-pro.com/party-themes/superhero-party/"
#   byapro_page_content = web_search(byapro_url)
#   print("By a Pro Page Content:", byapro_page_content)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# BizBash Page Content: ## Search Results
#
# [Catering & Design > Event Design & Decor | BizBash](https://www.bizbash.com/catering-design/event-design-decor)
# As more organizations place greater emphasis on experiential marketing, the design concept encompasses more than
# simply filling a room with decor—it's an opportunity to express the personality of a brand, nonprofit, or host. For
# event designers, the challenge lies in finding unique ways to impress guests. Whether you're planning a wedding,
# corporate event, meeting, gala, or other special ...
#
# [900+ Event Decor & Design Ideas | event decor, decor design ... -
# Pinterest](https://www.pinterest.com/bizbash/event-decor-design-ideas/)
# Take a look at some of the best event decor and design ideas we've spotted recently.
#
# [15 Ideas for Superhero-Themed Events -
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13479192/15-ideas-for-superheroth
# emed-events)
# New York's Robin Hood Foundation, which hosts one of the largest and most successful benefits in the city, tapped
# contacts at DC Comics to help create a superhero theme for its 2011 gala. The planning and design team created an
# emblem and slogan—"the forces of good are gathering"—that marked the night's invite and main cocktail area.
#
# [50+ Event Production & Strategy ideas | event, guest list, catering
# design](https://www.pinterest.com/bizbash/event-production-strategy/)
# May 5, 2023 - Stay up to date and get inspired with these event production and strategy ideas sure to wow your next
# guest-list. See more ideas about event, guest list, catering design.
#
# [Catering & Design - BizBash](https://www.bizbash.com/catering-design)
# Articles, news, products, blogs and videos covering the Catering & Design market.
#
# [BizBash Event Ideas (http://www.bizbash.com) -
# Pinterest](https://www.pinterest.com/dadlerbizbash/bizbash-event-ideas-httpwwwbizbashcom/)
# Mar 7, 2019 - As CEO of BizBash, I see everything. Here is my collection of what I like and want to spread the
# word. For more info go to my site- http://BizBash.com ...
#
# [Event Design |
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13358060/event-design)
# 16 Design and Catering Ideas to Inspire Your Summer Olympics-Themed Events From edible tennis balls to branded
# rock-climbing walls, these concepts are ideal for gatherings tied to the upcoming Olympic Games in Paris.
#
# [Event Ideas BizBash Spotted on
# Instagram](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/22940828/event-ideas-bizbash-sp
# otted-on-instagram)
# For your daily dose of event inspo from around the globe, follow BizBash on Instagram here. These creative design,
# lighting, and catering ideas across live events around the world served up some major eye candy on Instagram. Keep
# scrolling to see what our editors double-tapped...
#
# [Catering & Design > Rentals | BizBash](https://www.bizbash.com/catering-design/rentals)
# As tastes and trends change, rental companies refresh their options to help event planners create stylish,
# functional, and on-theme options for parties, weddings, corporate events, and more. From power-equipped tables and
# sleek seating options to on-theme tabletop and decor items, BizBash has compiled the latest rentals and trends.
# Read on for steal-worthy ideas for furniture, props and ...
#
# [BiZBash Awards Honor Best Event
# Ideas](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13471547/bizbash-awards-honor-best-
# event-ideas)
# Catering & Design Event Design & Decor BiZBash Awards Honor Best Event Ideas Guests at our Event Style Awards
# ceremony experienced an evening filled with entertainment, awards, and cabaret-style decor inside the B.B. King
# Blues Club & Grill.
# By a Pro Page Content: ## Search Results
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# Superhero party ideas by an award winning professional party planner including ideas for invitations, party food &
# drinks, decorations, and party supplies
#
# [Superhero Theme Party Ideas for Adults to Create an Unforgettable
# ...](https://partyideaszone.com/superhero-theme-party-ideas-for-adults/)
# Unleash your inner hero with our ultimate guide to hosting an unforgettable superhero-themed party for adults!
# Explore creative costume ideas, vibrant decorations, and mouthwatering themed snacks and drinks. Engage your guests
# with fun activities like trivia, costume contests, and movie screenings. Follow our planning tips to create a
# cohesive, memorable experience that your friends will rave ...
#
# [The Best Superhero Party Ideas For An Epic Party](https://smartpartyplanning.com/superhero-party-ideas/)
# Win the status of supermom with these superhero party ideas. Includes ideas for decorations, food and party games
# that kids will love.
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# 24 incredible superhero party ideas that kids will love and make adults wish they were kids again. From decor
# ideas, party foods, and costume ideas to superhero-themed activities, we have all of your party needs covered.
#
# [30+ Easy Superhero Party Ideas You Can Perfect on a
# Budget](https://www.frugalcouponliving.com/superhero-party-ideas/)
# Host a superhero-themed party that is sure to be a hit without a ton of time, money, or effort. Enjoy the best DIY
# superhero party ideas, recipes, décor, & games to make party planning easy-peasy.
#
# [Ideas for a Superhero Party! - Thimble and Twig](https://thimbleandtwig.com/ideas-superhero-party/)
# Superhero Party Ideas We opted for the Superhero party theme because we thought everyone probably needed a wee
# boost in remembering how wonderful they are and how we're all superheroes in our own special way! But there are all
# sorts of cake themes on the Baking Mad website. From Princess to pirate, Unicorn and Peter Rabbit - there are some
# fab party themes to make everything super easy ...
#
# [Mini Party Plan: How to Plan a Superhero Birthday
# Party](https://thepartyteacher.com/2018/08/23/mini-party-plan-superhero-party/)
# One of the most popular posts on this blog is a girl's superhero party. So I thought it might be fun to create a
# mini party plan for a superhero birthday party. I styled this mini party plan in the traditional red, yellow, and
# blue, but you could change the color palette for a more
#
# [Superhero Party Ideas | PartyWizz Blog](https://partywizz.com/blog/family/party-ideas/superhero-party-ideas/)
# If you're the parent of a superhero fanatic with a birthday in the offing, you'll want to carry on reading! Why?
# Because this article is your ultimate guide to throwing an unforgettable superhero-themed birthday bash! From DIY
# costume ideas to action-packed games and heroic snacks, we've thought of everything you could possibly need. > Hire
# a Superhero So, polish up your own super-power ...
#
# [Superhero Party Ideas - Theme A Party](https://themeaparty.com/superhero-party-ideas)
# Superhero Party Ideas So your youngster wants a superhero party. He's made a great choice - with all the superhero
# and comic book characters out there, there are a ton of different ways to organize one and make it truly special.
# Your special hero (or heroine) will likely have a favorite character in mind.
#
# [Super Hero Birthday Party - The Organized Mom](https://www.organizedmom.net/super-hero-birthday-party/)
# Do you have a little super hero kiddo who is obsessed with all the different super heroes? Then throwing a Super
# Hero Birthday Party is the only logical thing to do, am I right!?! You can plan a whole Super Hero party with all
# of those superhero theme party ideas. We're covering food, drinks, supplies, decorations and activities you can
# have at your Superhero birthday party!
#
# Out: None
# [Step 3: Duration 6.58 seconds| Input tokens: 10,008 | Output tokens: 401]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#
#   # Function to extract detailed content from the page content
#   def extract_details(text):
#       # Remove HTML tags and clean up the text
#       cleaned_text = re.sub('<[^>]*>', '', text).strip()
#
#       # Split text into paragraphs
#       paragraphs = cleaned_text.split('\n')
#
#       return paragraphs
#
#   # Get detailed content from BizBash link
#   bizbash_detailed_content = web_search(bizbash_url)
#   bizbash_paragraphs = extract_details(bizbash_detailed_content)
#
#   # Get detailed content from By a Pro link
#   byapro_detailed_content = web_search(byapro_url)
#   byapro_paragraphs = extract_details(byapro_detailed_content)
#
#   # Printing extracted paragraphs from BizBash
#   print("BizBash Paragraphs:\n", "\n".join(bizbash_paragraphs))
#
#   # Printing extracted paragraphs from By a Pro
#   print("By a Pro Paragraphs:\n", "\n".join(byapro_paragraphs))
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# BizBash Paragraphs:
#  ## Search Results
#
# [Catering & Design > Event Design & Decor | BizBash](https://www.bizbash.com/catering-design/event-design-decor)
# As more organizations place greater emphasis on experiential marketing, the design concept encompasses more than
# simply filling a room with decor—it's an opportunity to express the personality of a brand, nonprofit, or host. For
# event designers, the challenge lies in finding unique ways to impress guests. Whether you're planning a wedding,
# corporate event, meeting, gala, or other special ...
#
# [900+ Event Decor & Design Ideas | event decor, decor design ... -
# Pinterest](https://www.pinterest.com/bizbash/event-decor-design-ideas/)
# Take a look at some of the best event decor and design ideas we've spotted recently.
#
# [15 Ideas for Superhero-Themed Events -
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13479192/15-ideas-for-superheroth
# emed-events)
# New York's Robin Hood Foundation, which hosts one of the largest and most successful benefits in the city, tapped
# contacts at DC Comics to help create a superhero theme for its 2011 gala. The planning and design team created an
# emblem and slogan—"the forces of good are gathering"—that marked the night's invite and main cocktail area.
#
# [50+ Event Production & Strategy ideas | event, guest list, catering
# design](https://www.pinterest.com/bizbash/event-production-strategy/)
# May 5, 2023 - Stay up to date and get inspired with these event production and strategy ideas sure to wow your next
# guest-list. See more ideas about event, guest list, catering design.
#
# [Catering & Design - BizBash](https://www.bizbash.com/catering-design)
# Articles, news, products, blogs and videos covering the Catering & Design market.
#
# [BizBash Event Ideas (http://www.bizbash.com) -
# Pinterest](https://www.pinterest.com/dadlerbizbash/bizbash-event-ideas-httpwwwbizbashcom/)
# Mar 7, 2019 - As CEO of BizBash, I see everything. Here is my collection of what I like and want to spread the
# word. For more info go to my site- http://BizBash.com ...
#
# [Event Design |
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13358060/event-design)
# 16 Design and Catering Ideas to Inspire Your Summer Olympics-Themed Events From edible tennis balls to branded
# rock-climbing walls, these concepts are ideal for gatherings tied to the upcoming Olympic Games in Paris.
#
# [Event Ideas BizBash Spotted on
# Instagram](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/22940828/event-ideas-bizbash-sp
# otted-on-instagram)
# For your daily dose of event inspo from around the globe, follow BizBash on Instagram here. These creative design,
# lighting, and catering ideas across live events around the world served up some major eye candy on Instagram. Keep
# scrolling to see what our editors double-tapped...
#
# [Catering & Design > Rentals | BizBash](https://www.bizbash.com/catering-design/rentals)
# As tastes and trends change, rental companies refresh their options to help event planners create stylish,
# functional, and on-theme options for parties, weddings, corporate events, and more. From power-equipped tables and
# sleek seating options to on-theme tabletop and decor items, BizBash has compiled the latest rentals and trends.
# Read on for steal-worthy ideas for furniture, props and ...
#
# [BiZBash Awards Honor Best Event
# Ideas](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13471547/bizbash-awards-honor-best-
# event-ideas)
# Catering & Design Event Design & Decor BiZBash Awards Honor Best Event Ideas Guests at our Event Style Awards
# ceremony experienced an evening filled with entertainment, awards, and cabaret-style decor inside the B.B. King
# Blues Club & Grill.
# By a Pro Paragraphs:
#  ## Search Results
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# Superhero party ideas by an award winning professional party planner including ideas for invitations, party food &
# drinks, decorations, and party supplies
#
# [The Best Superhero Party Ideas For An Epic Party](https://smartpartyplanning.com/superhero-party-ideas/)
# Win the status of supermom with these superhero party ideas. Includes ideas for decorations, food and party games
# that kids will love.
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# 24 incredible superhero party ideas that kids will love and make adults wish they were kids again. From decor
# ideas, party foods, and costume ideas to superhero-themed activities, we have all of your party needs covered.
#
# [Superhero Theme Party Ideas for Adults to Create an Unforgettable
# ...](https://partyideaszone.com/superhero-theme-party-ideas-for-adults/)
# Unleash your inner hero with our ultimate guide to hosting an unforgettable superhero-themed party for adults!
# Explore creative costume ideas, vibrant decorations, and mouthwatering themed snacks and drinks. Engage your guests
# with fun activities like trivia, costume contests, and movie screenings. Follow our planning tips to create a
# cohesive, memorable experience that your friends will rave ...
#
# [Creative Superhero Party Snack Ideas for All Ages](https://playideas.com/25-superhero-party-ideas/)
# Discover creative superhero party snack ideas and decorations for all ages! Make your kid's birthday unforgettable
# with fun treats and crafts.
#
# [Ideas for a Superhero Party! - Thimble and Twig](https://thimbleandtwig.com/ideas-superhero-party/)
# Superhero Party Ideas We opted for the Superhero party theme because we thought everyone probably needed a wee
# boost in remembering how wonderful they are and how we're all superheroes in our own special way! But there are all
# sorts of cake themes on the Baking Mad website. From Princess to pirate, Unicorn and Peter Rabbit - there are some
# fab party themes to make everything super easy ...
#
# [Mini Party Plan: How to Plan a Superhero Birthday
# Party](https://thepartyteacher.com/2018/08/23/mini-party-plan-superhero-party/)
# One of the most popular posts on this blog is a girl's superhero party. So I thought it might be fun to create a
# mini party plan for a superhero birthday party. I styled this mini party plan in the traditional red, yellow, and
# blue, but you could change the color palette for a more
#
# [30+ Easy Superhero Party Ideas You Can Perfect on a
# Budget](https://www.frugalcouponliving.com/superhero-party-ideas/)
# Host a superhero-themed party that is sure to be a hit without a ton of time, money, or effort. Enjoy the best DIY
# superhero party ideas, recipes, décor, & games to make party planning easy-peasy.
#
# [Superhero Party Ideas | PartyWizz Blog](https://partywizz.com/blog/family/party-ideas/superhero-party-ideas/)
# If you're the parent of a superhero fanatic with a birthday in the offing, you'll want to carry on reading! Why?
# Because this article is your ultimate guide to throwing an unforgettable superhero-themed birthday bash! From DIY
# costume ideas to action-packed games and heroic snacks, we've thought of everything you could possibly need. > Hire
# a Superhero So, polish up your own super-power ...
#
# [Bam, Boom, Pow: 14 Superhero Birthday Party Ideas to Wow
# Guests](https://www.greenvelope.com/blog/superhero-birthday-party)
# Create an epic superhero birthday party with these top ideas, plus incredible invitations that'll help you share
# the excitement.
#
# Out: None
# [Step 4: Duration 7.10 seconds| Input tokens: 17,234 | Output tokens: 645]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Extract key points from BizBash
#   bizbash_key_points = web_search("NYC Robin Hood Foundation superhero-themed gala 2011")
#   print("BizBash Key Points:\n", bizbash_key_points)
#
#   # Extract key points from By a Pro
#   byapro_key_points = web_search("By a Pro superhero party ideas adults")
#   print("By a Pro Key Points:\n", byapro_key_points)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# BizBash Key Points:
#  ## Search Results
#
# [15 Ideas for Superhero-Themed Events -
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13479192/15-ideas-for-superheroth
# emed-events)
# New York's Robin Hood Foundation, which hosts one of the largest and most successful benefits in the city, tapped
# contacts at DC Comics to help create a superhero theme for its 2011 gala. The planning and design team created an
# emblem and slogan—"the forces of good are gathering"—that marked the night's invite and main cocktail area.
#
# [Robin Hood Gala Event 2011 | The Robin Hood Foundation's 2011 Gala
# ...](https://www.facebook.com/OAKES-174220752603154/videos/robin-hood-gala-event-2011/10150189702678901/)
# The Robin Hood Foundation's 2011 Gala Event was a huge success this year raising $47 million. We are proud to have
# designed the live event graphics for the 3rd year in a row. This year's theme...Superheroes! We will be posting the
# project in its entirety shortly but for now, here's a sample of what's to come.
#
# [Notable Guests of the Robin Hood Gala 2011 -
# CNBC](https://www.cnbc.com/2011/05/10/Notable-Guests-of-the-Robin-Hood-Gala-2011.html)
ults -
# Pinterest](https://www.pinterest.com/ideas/superhero-party-ideas-for-adults/937573028074/)
# Find and save ideas about superhero party ideas for adults on Pinterest.
#
# [21 Hilarious Superhero Party Games Kids & Adults Will Both
# Love](https://www.playpartyplan.com/superhero-minute-to-win-it-games-for-kids/)
# Entertain your family and friends with these hilarious superhero minute to win it games with items from home!
# Superhero party games everyone will love no matter their age! Superhero games inspired by The Avengers, Justice
# League superheroes, and more!
#
# [30+ Superhero Party Ideas - Canva](https://www.canva.com/ideas/superhero-party-ideas/)
# Bright-colored capes, superhero masks for everyone, colorful hero cupcakes - all these ingenious concepts and more
# are in our special selection of superhero-themed designs and photos. Have a quick browse and find some excellent
# ideas for your party!
#
# [30+ Easy Superhero Party Ideas You Can Perfect on a
# Budget](https://www.frugalcouponliving.com/superhero-party-ideas/)
# Host a superhero-themed party that is sure to be a hit without a ton of time, money, or effort. Enjoy the best DIY
# superhero party ideas, recipes, décor, & games to make party planning easy-peasy.
#
# [Fantastic Decorating Ideas for an Adult Superhero
# Party](https://celebrateeverydaywithme.com/fantastic-decorating-ideas-for-an-adult-superhero-party/)
# Looking for creative ideas for an adult superhero party? You've come to the right place! Check out the
# centerpieces, diy photo booth and room decor for our fun parents' night out event.
#
# [Superhero-Themed Party Ideas & Decorations |
# CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# Marvel™ Superhero-Themed Party Ideas Superhero-themed parties have become a beloved trend, offering an exciting way
# to celebrate special occasions. The thrill of donning capes and masks, the vibrant decorations, and the heroic
# atmosphere make these parties a hit among kids and adults alike.
#
# [Superhero Party Games and Activities - Captain Fantastic
# US](https://cfparties.com/blog/superhero-party-games-and-activities/)
# Superhero Party Games and Activities Design Your Superhero Costume: Get creative with your superhero costume by
# designing a unique ensemble that reflects your character's personality. Consider colors, symbols, and accessories
# that represent your superhero's powers and traits.
#
# Out: None
# [Step 5: Duration 6.97 seconds| Input tokens: 26,681 | Output tokens: 814]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Define a function to extract relevant section from text
#   def extract_section(text, keyword):
#       # Find the index of the keyword
#       start_index = text.lower().find(keyword.lower())
#
#       if start_index == -1:
#           return f"Keyword '{keyword}' not found."
#
#       # Extract the paragraph containing the keyword
#       start_of_paragraph = text.rfind('\n', 0, start_index) + 1
#       end_of_paragraph = text.find('\n', start_index)
#
#       if end_of_paragraph == -1:
#           end_of_paragraph = len(text)
#
#       return text[start_of_paragraph:end_of_paragraph]
#
#   # BizBash Key Points parsing
#   bizbash_decorations = extract_section(bizbash_key_points, "planning and design team created")
#   bizbash_catering = extract_section(bizbash_key_points, "cocktail area")
#   print("BizBash Decorations:", bizbash_decorations)
#   print("BizBash Catering:", bizbash_catering)
#
#   # By a Pro Key Points parsing
#   byapro_decorations = extract_section(byapro_key_points, "vibrant decorations")
#   byapro_entertainment = extract_section(byapro_key_points, "fun activities")
#   byapro_catering = extract_section(byapro_key_points, "mouthwatering themed snacks and drinks")
#   print("By a Pro Decorations:", byapro_decorations)
#   print("By a Pro Entertainment:", byapro_entertainment)
#   print("By a Pro Catering:", byapro_catering)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# BizBash Decorations: New York's Robin Hood Foundation, which hosts one of the largest and most successful benefits
# in the city, tapped contacts at DC Comics to help create a superhero theme for its 2011 gala. The planning and
# design team created an emblem and slogan—"the forces of good are gathering"—that marked the night's invite and main
# cocktail area.
# ...
# is as epic as the comics and movies themselves ...
#
# [Superhero Party Ideas for Adults -
# Pinterest](https://www.pinterest.com/ideas/superhero-party-ideas-for-adults/937573028074/)
# Find and save ideas about superhero party ideas for adults on Pinterest.
#
# [Marvel Themed Party Ideas for Adults: Unleash Your Inne -
# Toxigon](https://toxigon.com/marvel-themed-party-ideas-for-adults)
#
...](https://partyideaszone.com/superhero-theme-party-ideas-for-adults/)
# Unleash your inner hero with our ultimate guide to hosting an unforgettable superhero-themed party for adults!
# Explore creative costume ideas, vibrant decorations, and mouthwatering themed snacks and drinks.
#
# Out: None
# [Step 9: Duration 15.01 seconds| Input tokens: 89,197 | Output tokens: 2,681]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 10 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Summarize findings from BizBash and By a Pro
#
#   luxury_superhero_party_ideas = {
#       "Decorations": [
#           "Vibrant decorations featuring superhero symbolism.",
#           "Custom props and designs.",
#           "Backlit panels with city skyline imagery (e.g., NYC skyline).",
#           "Large, eye-catching design elements.",
#           "DC Comics-inspired decorations."
#       ],
#       "Entertainment": [
#           "Live-streamed discussions.",
#           "Full-length concerts (e.g., Lady Gaga).",
#           "Fun activities like trivia, costume contests, and movie screenings.",
#           "Interactive games that engage both adults and kids."
#       ],
#       "Catering": [
#           "Mouthwatering themed snacks and drinks.",
#           "Superhero-inspired cocktails.",
#           "Custom cocktails and recipes suitable for adults."
#       ]
#   }
#
#   print("Luxury Superhero Party Ideas Summary:", luxury_superhero_party_ideas)
#
#   # Convert the summary to a readable format for the final answer
#   summary_text = (
#       "Luxury Superhero Party Ideas:\n"
#       "\nDecorations:\n- " + "\n- ".join(luxury_superhero_party_ideas["Decorations"]) + "\n"
#       "\nEntertainment:\n- " + "\n- ".join(luxury_superhero_party_ideas["Entertainment"]) + "\n"
#       "\nCatering:\n- " + "\n- ".join(luxury_superhero_party_ideas["Catering"])
#   )
#
#   final_answer(summary_text)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Luxury Superhero Party Ideas Summary: {'Decorations': ['Vibrant decorations featuring superhero symbolism.',
# 'Custom props and designs.', 'Backlit panels with city skyline imagery (e.g., NYC skyline).', 'Large, eye-catching
# design elements.', 'DC Comics-inspired decorations.'], 'Entertainment': ['Live-streamed discussions.', 'Full-length
# concerts (e.g., Lady Gaga).', 'Fun activities like trivia, costume contests, and movie screenings.', 'Interactive
# games that engage both adults and kids.'], 'Catering': ['Mouthwatering themed snacks and drinks.',
# 'Superhero-inspired cocktails.', 'Custom cocktails and recipes suitable for adults.']}
#
# Out - Final answer: Luxury Superhero Party Ideas:
#
# Decorations:
# - Vibrant decorations featuring superhero symbolism.
# - Custom props and designs.
# - Backlit panels with city skyline imagery (e.g., NYC skyline).
# - Large, eye-catching design elements.
# - DC Comics-inspired decorations.
#
# Entertainment:
# - Live-streamed discussions.
# - Full-length concerts (e.g., Lady Gaga).
# - Fun activities like trivia, costume contests, and movie screenings.
# - Interactive games that engage both adults and kids.
#
# Catering:
# - Mouthwatering themed snacks and drinks.
# - Superhero-inspired cocktails.
# - Custom cocktails and recipes suitable for adults.
# [Step 10: Duration 6.70 seconds| Input tokens: 115,577 | Output tokens: 3,130]
# Luxury Superhero Party Ideas:
#
# Decorations:
# - Vibrant decorations featuring superhero symbolism.
# - Custom props and designs.
# - Backlit panels with city skyline imagery (e.g., NYC skyline).
# - Large, eye-catching design elements.
# - DC Comics-inspired decorations.
#
# Entertainment:
# - Live-streamed discussions.
# - Full-length concerts (e.g., Lady Gaga).
# - Fun activities like trivia, costume contests, and movie screenings.
# - Interactive games that engage both adults and kids.
#
# Catering:
# - Mouthwatering themed snacks and drinks.
# - Superhero-inspired cocktails.
# - Custom cocktails and recipes suitable for adults.

# %% [markdown]
# The agent follows this process:
#
# 1. **Analyzes the Request:** Alfred’s agent identifies the key elements of the query—luxury superhero-themed party planning, with focus on decor, entertainment, and catering.
# 2. **Performs Retrieval:**  The agent leverages DuckDuckGo to search for the most relevant and up-to-date information, ensuring it aligns with Alfred’s refined preferences for a luxurious event.
# 3. **Synthesizes Information:** After gathering the results, the agent processes them into a cohesive, actionable plan for Alfred, covering all aspects of the party.
# 4. **Stores for Future Reference:** The agent stores the retrieved information for easy access when planning future events, optimizing efficiency in subsequent tasks.

# %% [markdown]
# ## Custom Knowledge Base Tool
#
# For specialized tasks, a custom knowledge base can be invaluable. Let's create a tool that queries a vector database of technical documentation or specialized knowledge. Using semantic search, the agent can find the most relevant information for Alfred's needs.
#
# This approach combines predefined knowledge with semantic search to provide context-aware solutions for event planning. With specialized knowledge access, Alfred can perfect every detail of the party.
#
# Install the dependecies first and run!

# %%
# !pip install langchain-community rank_bm25
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.26-py3-none-any.whl.metadata (2.9 kB)
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.66)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.26-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 29.7 MB/s eta 0:00:00
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.9 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.9 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: rank_bm25, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.1 langchain-community-0.3.26 marshmallow-3.26.1 mypy-extensions-1.1.0 pydantic-settings-2.10.1 rank_bm25-0.2.2 typing-inspect-0.9.0

# %%
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from smolagents import Tool
from langchain_community.retrievers import BM25Retriever
from smolagents import CodeAgent, InferenceClientModel

class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = "Uses semantic search to retrieve relevant party planning ideas for Alfred’s superhero-themed party at Wayne Manor."
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or superhero themes.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=5  # Retrieve the top 5 documents
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retriever.invoke(
            query,
        )
        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# Simulate a knowledge base about party planning
party_ideas = [
    {"text": "A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.", "source": "Party Ideas 1"},
    {"text": "Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.", "source": "Entertainment Ideas"},
    {"text": "For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'", "source": "Catering Ideas"},
    {"text": "Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.", "source": "Decoration Ideas"},
    {"text": "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.", "source": "Entertainment Ideas"}
]

source_docs = [
    Document(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in party_ideas
]

# Split the documents into smaller chunks for more efficient search
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    add_start_index=True,
    strip_whitespace=True,
    separators=["\n\n", "\n", ".", " ", ""],
)
docs_processed = text_splitter.split_documents(source_docs)

# Create the retriever tool
party_planning_retriever = PartyPlanningRetrieverTool(docs_processed)

# Initialize the agent
agent = CodeAgent(tools=[party_planning_retriever], model=InferenceClientModel())

# Example usage
response = agent.run(
    "Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options."
)

print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options.      │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   query = "luxury superhero-themed party ideas entertained catering decoration"
#   results = party_planning_retriever(query=query)
#   print(results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
#
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 1: Duration 1.29 seconds| Input tokens: 2,017 | Output tokens: 79]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   ideas = {
#       "entertainment": [
#           "Professional DJ playing themed music for superheroes like Batman and Wonder Woman",
#           "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed
#   games"
#       ],
#       "catering": [
#           "Serving dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power
#   Steak'",
#           "Luxury cocktail station with signature superhero drinks"
#       ],
#       "decoration": [
#           "Superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains",
#           "Decorating with iconic superhero logos and projections of Gotham and other superhero cities around the
#   venue",
#           "Large LED screen displaying superhero movie clips or interviews",
#           "Giant inflatable balloons and banners featuring famous superheroes"
#       ]
#   }
#
#   for category, options in ideas.items():
#       print(f"{category.capitalize()} Options:")
#       for option in options:
#           print(f"- {option}")
#       print()
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Entertainment Options:
# - Professional DJ playing themed music for superheroes like Batman and Wonder Woman
# - Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games
#
# Catering Options:
# - Serving dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak'
# - Luxury cocktail station with signature superhero drinks
#
# Decoration Options:
# - Superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains
# - Decorating with iconic superhero logos and projections of Gotham and other superhero cities around the venue
# - Large LED screen displaying superhero movie clips or interviews
# - Giant inflatable balloons and banners featuring famous superheroes
#
#
# Out: None
# [Step 2: Duration 3.10 seconds| Input tokens: 4,330 | Output tokens: 327]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   summary = (
#       "Luxury Superhero-Themed Party Ideas:\n\n"
#       "Entertainment Options:\n"
#       f"{ideas['entertainment'][0]}\n"
#       f"{ideas['entertainment'][1]}\n\n"
#
#       "Catering Options:\n"
#       f"{ideas['catering'][0]}\n"
#       f"{ideas['catering'][1]}\n\n"
#
#       "Decoration Options:\n"
#       f"{ideas['decoration'][0]}\n"
#       f"{ideas['decoration'][1]}\n"
#       f"{ideas['decoration'][2]}\n"
#       f"{ideas['decoration'][3]}"
#   )
#
#   final_answer(summary)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: Luxury Superhero-Themed Party Ideas:
#
# Entertainment Options:
# Professional DJ playing themed music for superheroes like Batman and Wonder Woman
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games
#
# Catering Options:
# Serving dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak'
# Luxury cocktail station with signature superhero drinks
#
# Decoration Options:
# Superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains
# Decorating with iconic superhero logos and projections of Gotham and other superhero cities around the venue
# Large LED screen displaying superhero movie clips or interviews
# Giant inflatable balloons and banners featuring famous superheroes
# [Step 3: Duration 2.58 seconds| Input tokens: 7,315 | Output tokens: 517]
# Luxury Superhero-Themed Party Ideas:
#
# Entertainment Options:
# Professional DJ playing themed music for superheroes like Batman and Wonder Woman
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games
#
# Catering Options:
# Serving dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak'
# Luxury cocktail station with signature superhero drinks
#
# Decoration Options:
# Superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains
# Decorating with iconic superhero logos and projections of Gotham and other superhero cities around the venue
# Large LED screen displaying superhero movie clips or interviews
# Giant inflatable balloons and banners featuring famous superheroes

# %% [markdown]
# This enhanced agent can:
# 1. First check the documentation for relevant information
# 2. Combine insights from the knowledge base
# 3. Maintain conversation context through memory
